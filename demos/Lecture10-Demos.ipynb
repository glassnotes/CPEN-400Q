# %% [markdown]
# # Demos: Lecture 10

# %% [markdown]
# ## Demo 1: Grover's algorithm

# %% [markdown]
# <img src="fig/grover_circuit_full_c.png" width="500px">

# %%
import pennylane as qml
import numpy as np

# %%
n_bits = 5
special_string = '01001' 

dev = qml.device('default.qubit', wires=n_bits+1)

# %%
def hadamard_transform(wires):
    for wire in wires:
        qml.Hadamard(wires=wire)

# %%
def oracle():
    qml.MultiControlledX(control_wires=list(range(n_bits)), wires=n_bits, control_values=special_string)

# %%
def diffusion():
    hadamard_transform(list(range(n_bits)))
    qml.MultiControlledX(control_wires=list(range(n_bits)), wires=n_bits, control_values="0"*n_bits)
    hadamard_transform(list(range(n_bits)))

# %%
@qml.qnode(dev)
def grover(num_its):
    qml.PauliX(wires=n_bits)
    hadamard_transform(wires=list(range(n_bits+1)))

    for _ in range(num_its):
        oracle()
        diffusion()

    return qml.probs(wires=range(n_bits))

# %% [markdown]
# For plotting after the implementation

# %%
import matplotlib.pyplot as plt

for n in range(10):
    plt.bar(
        list(range(2 ** n_bits)),
        grover(num_its=n),
        label=f"it={n}"
    )
    plt.ylim(0, 1)
    plt.legend()
    plt.show()
# Out:
# /home/olivia/Software/anaconda3/envs/cpen400q/lib/python3.12/site-packages/pennylane/ops/qubit/non_parametric_ops.py:2095: UserWarning: The control_wires keyword will be removed soon. Use wires = (control_wires, target_wire) instead. See the documentation for more information.
#   warnings.warn(
